# %% [markdown]
# # **Hugging Face Backup**
#
# Welcome to our peculiar repository!
#
# This project is a unique amalgamation of content from Nocrypt's notebook and EveryDream2Trainer for JupyterLabs, curated by a diverse DID system with a passion for experimentation. We affectionately call it "opinionated," reflecting our unconventional approach.
#
# The primary goal of this repository is to facilitate the quick upload of merged models to Hugging Face. While our focus is on functionality, we prioritize simplicity and accessibility. Currently, this repository supports checkpoints rather than full backups, optimized for local machine usage. There is different diffusers edition that has not been updated in a while, but functionality is similar to this one.  This notebook is limited to Jupyter Enivronments, and is not set up to work with Google Colab.  This will work on Amazon Sagemaker, Vast.Ai, Runpod & anywhere that supports Jupyter Labs.
#
# If you've copied this to drive and it's no longer working check [here](https://github.com/duskfallcrew/HuggingFace_Backup)
#
# If you're on CivitAI, the version SHOULD be updated as soon as a version has been pushed!
#
# If you want me to learn more programming, or want to fund my absolute nightmare of upcoming costs for model training:
#
# [![ko-fi](https://ko-fi.com/img/githubbutton_sm.svg)](https://ko-fi.com/Z8Z8L4EO)
#
# -----------------
# ### **Important Note:**
#
#
# Before diving in, ensure you create a Hugging Face token with write permissions. Follow this link for instructions on token creation.
#
# You need to create a huggingface token, go to [this link](https://huggingface.co/settings/tokens), then `create new token` or copy available token with the `Write` role.
#
# -----------------
#
# ### Support?
#
# Bugs can be tracked via the PR & Bug tracker on github, or Civitai DM/comment system, or via the Earth & Dusk Discord.
#
# -----------------
#
# ### Collaboration
#
# I am NOT A programmer by nature, I patch with what little knowledge I have. I Failed programming several times over the years, so if something needs cleaning up and you want to patch it - pull request it!
#
# -----------------
# ## About & Sponsored
#
# We are a system of over 300 alters, proudly navigating life with Dissociative Identity Disorder, ADHD, Autism, and CPTSD. We believe in the potential of AI to break down barriers and enhance aspects of mental health, even as it presents challenges. Our creative journey is an ongoing exploration of identity and expression, and we invite you to join us in this adventure.
#
# ###  Join Our Community:
# We're always looking for more content creators to collaborate with and support. Join us on our various platforms:
#
# Website: [End Media](https://www.end-media.org/)
#
# Discord: [Join our Discord](https://discord.gg/5t2kYxt7An)
#
# Backups: [Hugging Face](https://huggingface.co/EarthnDusk)
#
# Support Us: [Send a Pizza](https://ko-fi.com/duskfallcrew)
#
# Youtube: [Duskfall Music & More](https://www.youtube.com/channel/UCk7MGP7nrJz5awBSP75xmVw)
#
# Spotify: [PLAYLIST](https://open.spotify.com/playlist/00R8x00YktB4u541imdSSf?si=57a8f0f0fe87434e)
#
# [DeviantArt Group](https://www.deviantart.com/diffusionai)
#
# [Subreddit](https://www.reddit.com/r/earthndusk/)
#
#
# -----------------
#
# ### Proudly Supported By:
#
# [Pirate Diffusion](https://www.piratediffusion.com/)
#
# [Yodayo](https://yodayo.com/)
#
#
# -----------------
#
# ## ***Forked from - EVERYDREAM2 TRAINER - LINAQRUF - AND NOCRYPT ***
#
# Credtis for original codes for Colab - NOCRYPT
# [![](https://dcbadge.vercel.app/api/shield/442099748669751297?style=flat)](https://lookup.guru/442099748669751297) [![ko-fi](https://img.shields.io/badge/Ko--fi-F16061?logo=ko-fi&logoColor=white&style=flat)](https://ko-fi.com/nocrypt) [![ko-fi](https://img.shields.io/badge/Patreon-F1465A?logo=patreon&logoColor=white&style=flat)](https://patreon.com/nocrypt)
#
# Open the SD Colab here:
# <a target="_blank" href="https://colab.research.google.com/drive/1wEa-tS10h4LlDykd87TF5zzpXIIQoCmq">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# ###  Jupyter/EveryDream:
# **https://github.com/victorchall/EveryDream2trainer**
#
# -----------------
#
#
# #### CHANGELOG JUPYTER EDITION
#
# 1 Incorporated 90% of the code from EveryDream2Trainer (by Victorchall), specifically the Python widget near the bottom.
#
# 2 Acknowledged Nocrypt for the original contributions and maintained proper credit.
#
# 3 Attempted to include all necessary requirements within the Jupyter notebook. If anything is missing, please let me know.
#
# 4 Admitting to my limited programming skills—feel free to fork and modify this project on github.
#
# 5 Corrected the code from all_ckpts = f for f in glob.glob"*.safetensor" to all_ckpts = f for f in glob.glob "*.safetensors" to ensure proper functionality.
#
# 6 Added instructions using my own natural language for clarity.
#
# 7 Translated the instructions to GPT and added them to GitHub.
#
# 8 Enhanced the Jupyter edition with clearer instructions.
#
# 9 Set a reminder to update the Colab version to reflect the latest changes.
#
# 10 Updated Colab to mostly match Jupyter, and fixed both folder uploaders to have extra functions thanks to Chat GPT.
#
#
# -----------------

# %% [markdown]
# # Installation & Requirements
# -----------------
#
# This setup is designed to collect all necessary requirements. However, if you encounter any missing dependencies, please be patient for an update or address the issue manually in the terminal. (Note: While I strive to address issues promptly, my strength lies in patching rather than programming. Your understanding is appreciated!)

# %%
# !pip install glob2
# !pip install --force-reinstall -qqqq huggingface_hub
# !pip install transformers
# !pip install ipywidgets
# Out:
# Collecting glob2
#   Using cached glob2-0.7-py2.py3-none-any.whl
# Installing collected packages: glob2
# Successfully installed glob2-0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tokenizers 0.14.1 requires huggingface_hub<0.18,>=0.16.4, but you have huggingface-hub 0.18.0 which is incompatible.
# Requirement already satisfied: transformers in /Users/duskfall/miniconda3/lib/python3.10/site-packages (4.34.1)
# Requirement already satisfied: filelock in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (0.18.0)
# Requirement already satisfied: requests in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: numpy>=1.17 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (1.26.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: packaging>=20.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.10.0)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Using cached huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: huggingface-hub
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.18.0
#     Uninstalling huggingface-hub-0.18.0:
#       Successfully uninstalled huggingface-hub-0.18.0
# Successfully installed huggingface-hub-0.17.3
# Requirement already satisfied: ipywidgets in /Users/duskfall/miniconda3/lib/python3.10/site-packages (8.1.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: ipython>=6.1.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipywidgets) (8.16.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: appnope in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.3)
# Requirement already satisfied: matplotlib-inline in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: exceptiongroup in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: decorator in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: stack-data in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: backcall in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.0)
# Requirement already satisfied: pure-eval in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/duskfall/miniconda3/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %% [markdown]
# # HuggingFace Upload/Download
# -----------------
#
# Run the cell below and paste your Access/Account token into the text box.  You can get your token from your [huggingface account page](https://huggingface.co/settings/tokens).
#
# The token will not show on the screen, just press enter after you paste it.
#
# ### Make sure to run this login cell for any Huggingface uploads or private downloads.

# %%
from huggingface_hub import notebook_login, hf_hub_download
import os
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Upload files from a folder (Single files)
# -----------------
#
#
# Please ensure that you have noted where you are uploading your files in the "REPO" section. Follow these steps to create a new repository on your Hugging Face account:
#
# [Navigate to Your Hugging Face Account](https://huggingface.co/)
#
# Visit the Hugging Face website and log in to your account via the above link
#
# Go to your user profile page.
# [Click on the "New  Model" button.](https://huggingface.co/new)
# Enter a name for your model repository.
# Choose the appropriate settings and permissions.
#
#
# Note the name of the newly created repository for use in your Jupyter Lab setup. Unlike Colab, which can automatically create a repository, Jupyter Lab requires a pre-created repository. This setup should allow you to upload all necessary files to your repository seamlessly.

# %%
import glob
import os
from huggingface_hub import HfApi
from ipywidgets import *
from IPython.display import display
from pathlib import Path

# Define widgets for user inputs
file_type = Text(value='safetensors', placeholder='File Type (e.g., safetensors)', description='File Type:')
sort_by = Dropdown(options=['name', 'date'], value='name', description='Sort By:')
hfuser = Text(placeholder='EarthNDusk', description='HF User:')
hfrepo = Text(placeholder='July_2024_Backup_Full_Models', description='HF Repo:')
update_btn = Button(description='Update Files')
upload_btn = Button(description='Upload')
out = Output()

# Initialize Hugging Face API
api = HfApi()

# Define function to update file list
def update_files(_):
    global ckpt_picker
    file_extension = file_type.value
    all_ckpts = [f for f in glob.glob(f"*.{file_extension}")]
    
    if sort_by.value == 'date':
        all_ckpts.sort(key=os.path.getmtime)
    else:
        all_ckpts.sort()

    ckpt_picker.options = all_ckpts

# Define upload function
def upload_ckpts(_):
    repo_id = f"{hfuser.value or hfuser.placeholder}/{hfrepo.value or hfrepo.placeholder}"
    with out:
        if ckpt_picker is None or len(ckpt_picker.value) < 1:
            print("Nothing selected for upload, make sure to select one of the checkpoint files in the list, or verify there are checkpoint files in the specified directory.")
        for ckpt in ckpt_picker.value:
            print(f"Uploading to HF: huggingface.co/{repo_id}/{os.path.basename(ckpt)}")
            response = api.upload_file(
                path_or_fileobj=ckpt,
                path_in_repo=os.path.basename(ckpt),
                repo_id=repo_id,
                repo_type=None,
                create_pr=1,
                commit_message="Upload with Earth & Dusk Huggingface 🤗 Backup"
            )
            display(response)
        print("DONE")
        print("Go to your repo and accept the PRs created to see your files.")

# Bind the functions to buttons
update_btn.on_click(update_files)
upload_btn.on_click(upload_ckpts)

# Create and display the widget layout
ckpt_picker = SelectMultiple(options=[], layout=Layout(width="600px"))
box = VBox([
    file_type,
    sort_by,
    HBox([hfuser, hfrepo]),
    update_btn,
    ckpt_picker,
    upload_btn,
    out
])

display(box)
# Out:
# VBox(children=(SelectMultiple(layout=Layout(width='600px'), options=('sd_xl_base_1.0.safetensors', 'sd_xl_refi…
